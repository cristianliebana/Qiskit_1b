# %%
from qiskit import QuantumCircuit, QuantumRegister, transpile, assemble, ClassicalRegister
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# %%
# Crear un circuito de 3 qubits y 3 bits clásicos
num_qubits = 3

# Crear un registro cuántico y un registro clásico
qc = QuantumCircuit(num_qubits, num_qubits)

qc.h([2])
qc.cx([1],[2])
qc.tdg([2])
qc.cx([0],[2])
qc.t([2])
qc.cx([1],[2])
qc.t([1])
qc.tdg([2])
qc.cx([0],[2])
qc.cx([0],[1])
qc.t([2])
qc.h([2])
qc.tdg([1])
qc.t([0])
qc.cx([0],[1])

# Medir los qubits
qc.measure([0,1,2], [0,1,2])

# Dibujar el circuito
qc.draw('mpl')

# %%
# Estado de entrada (por ejemplo, |111⟩)
input_state = [1, 1, 1]

# Aplicar la puerta inicial al estado de entrada
qc.initialize(input_state, [0, 1, 2])

# Simular el circuito
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
output_state = result.get_statevector()

print("Estado de entrada:", input_state)
print("Estado de salida:", output_state)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[48], line 5
#       2 input_state = [1, 1, 1]
#       4 # Aplicar la puerta inicial al estado de entrada
# ----> 5 qc.initialize(input_state, [0, 1, 2])
#       7 # Simular el circuito
#       8 simulator = Aer.get_backend('statevector_simulator')
#
# File ~\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:5812, in QuantumCircuit.initialize(self, params, qubits, normalize)
#    5808     qubits = [qubits]
#    5810 num_qubits = len(qubits) if isinstance(params, int) else None
# -> 5812 return self.append(Initialize(params, num_qubits, normalize), qubits, copy=False)
#
# File ~\anaconda3\Lib\site-packages\qiskit\circuit\library\data_preparation\initializer.py:66, in Initialize.__init__(self, params, num_qubits, normalize)
#      41 def __init__(
#      42     self,
# ...
